# %%
# 1. Arithmetic Operators
a = 10
b = 3

print("Arithmetic Operators:")
print(f"{a} + {b} =", a + b)  # Addition
print(f"{a} - {b} =", a - b)  # Subtraction
print(f"{a} * {b} =", a * b)  # Multiplication
print(f"{a} / {b} =", a / b)  # Division
print(f"{a} // {b} =", a // b)  # Floor Division
print(f"{a} % {b} =", a % b)  # Modulus
print(f"{a} ** {b} =", a ** b)  # Exponentiation

# 2. Comparison (Relational) Operators
print("\nComparison Operators:")
print(f"{a} == {b}:", a == b)  # Equal to
print(f"{a} != {b}:", a != b)  # Not equal to
print(f"{a} > {b}:", a > b)  # Greater than
print(f"{a} < {b}:", a < b)  # Less than
print(f"{a} >= {b}:", a >= b)  # Greater than or equal to
print(f"{a} <= {b}:", a <= b)  # Less than or equal to

# 3. Logical Operators
x = True
y = False

print("\nLogical Operators:")
print(f"{x} and {y}:", x and y)  # Logical AND
print(f"{x} or {y}:", x or y)  # Logical OR
print(f"not {x}:", not x)  # Logical NOT

# 4. Bitwise Operators
m = 5  # 0101 in binary
n = 3  # 0011 in binary

print("\nBitwise Operators:")
print(f"{m} & {n}:", m & n)  # Bitwise AND
print(f"{m} | {n}:", m & n)  # Bitwise OR
print(f"{m} ^ {n}:", m ^ n)  # Bitwise XOR
print(f"~{m}:", ~m)  # Bitwise NOT
print(f"{m} << 1:", m << 1)  # Bitwise left shift
print(f"{m} >> 1:", m >> 1)  # Bitwise right shift

# 5. Assignment Operators
c = 10
print("\nAssignment Operators:")
c += 5  # c = c + 5
print("c += 5:", c)
c -= 3  # c = c - 3
print("c -= 3:", c)
c *= 2  # c = c * 2
print("c *= 2:", c)
c /= 4  # c = c / 4
print("c /= 4:", c)
c %= 3  # c = c % 3
print("c %= 3:", c)
c //= 2  # c = c // 2
print("c //= 2:", c)
c **= 2  # c = c ** 2
print("c **= 2:", c)
c &= 1  # c = c & 1
print("c &= 1:", c)
c |= 2  # c = c | 2
print("c |= 2:", c)
c ^= 1  # c = c ^ 1
print("c ^= 1:", c)
c <<= 1  # c = c << 1
print("c <<= 1:", c)
c >>= 1  # c = c >> 1
print("c >>= 1:", c)

# 6. Identity Operators
d = [1, 2, 3]
e = [1, 2, 3]
f = d

print("\nIdentity Operators:")
print("d is e:", d is e)  # False, because they are different objects
print("d is f:", d is f)  # True, because f is the same object as d
print("d is not e:", d is not e)  # True
print("d is not f:", d is not f)  # False

# 7. Membership Operators
g = [1, 2, 3, 4, 5]

print("\nMembership Operators:")
print("2 in g:", 2 in g)  # True
print("6 in g:", 6 in g)  # False
print("3 not in g:", 3 not in g)  # False
print("6 not in g:", 6 not in g)  # True
# Out:
# Arithmetic Operators:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.3333333333333335
# 10 // 3 = 3
# 10 % 3 = 1
# 10 ** 3 = 1000
#
# Comparison Operators:
# 10 == 3: False
# 10 != 3: True
# 10 > 3: True
# 10 < 3: False
# 10 >= 3: True
# 10 <= 3: False
#
# Logical Operators:
# True and False: False
# True or False: True
# not True: False
#
# Bitwise Operators:
# 5 & 3: 1
# 5 | 3: 1
# 5 ^ 3: 6
# ~5: -6
# 5 << 1: 10
# 5 >> 1: 2
#
# Assignment Operators:
# c += 5: 15
# c -= 3: 12
# c *= 2: 24
# c /= 4: 6.0
# c %= 3: 0.0
# c //= 2: 0.0
# c **= 2: 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 61
#      59 c **= 2  # c = c ** 2
#      60 print("c **= 2:", c)
# ---> 61 c &= 1  # c = c & 1
#      62 print("c &= 1:", c)
#      63 c |= 2  # c = c | 2
#
# TypeError: unsupported operand type(s) for &=: 'float' and 'int'
